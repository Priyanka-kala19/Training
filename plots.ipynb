# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1= pd.read_csv('df1',index_col=0)

# %%
df2=pd.read_csv('df2')

# %%
df3=pd.read_csv('df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
### graph function


1. plot-                         simple line plot
2. plot.area-                    filled version of line plot
3.plot.bar / plot-               bar graph
4. plot.box-                     box plot 
5. plot.density-                 density line(smooth curved)
6.plot.hist -                    histogram 
7. plot.pie-                     pie chart of categorical data 
8. plot.scatter-                 scatter graph 
9. plot.kdl-                     kernel density estimator(density graph)
10. plot.hexbin-                 hexagon version of scatter with density
# Out:
#   Input In [12]
#     1. plot-                         simple line plot
#        ^
# SyntaxError: invalid syntax

# %%
fig=plt.figure(figsize=(20,20))
df2.plot();plt.title('line plot');plt.show()
df2.plot.area();plt.title('area plot');plt.show()
df2.plot.bar();plt.title('bar plot');plt.show()
df2.plot.hist();plt.title('histogram plot');plt.show()
df2.plot.box();plt.title('box plot');plt.show()
df2.plot.density();plt.title('density plot');plt.show()
df2.plot.kde();plt.title('kde plot');plt.show()
df2.plot.barh();plt.title('bar horizontal plot');plt.show()
df2.plot.scatter(x='a',y='b');plt.title('scatter plot');plt.show()
plt.subplot();df2.plot.hexbin(x='a',y='b',C='c',gridsize=6);plt.title('hexbin plot');plt.show()

df2['a'].plot.hist();plt.title('histogram plot for only A');plt.show()

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df4=pd.DataFrame({'gift':[40,60,80,30],'name':['rahul','vinita','vijay','suman']})

# %%
plt.figure(figsize=[5,5])
df4['gift'].plot.pie(autopct='%d%%',labels=df4['name'])
# Out:
# <AxesSubplot:ylabel='gift'>

# %%
# importing seaborn
import seaborn as sns

# %%
### Categories
from pandas import Categorical


1. Categorical plots        (hue can be used | comparision with Categorical data)
    a.countplot
    b.barplot               (one Categorical, one numerical and also calculate mean )
    c.boxplot
    d.violinplot
    e.swarmplot
2. Distribution plots 
    a.distplot
    b.displot
    c.jointplot
    d.pairplot
    e.kdeplot
    f.rugplot
    g.scatterplot
3. Matrix plots 
    a.heatmap
    b.clustermap
    c.pairplot (same as above one)
4. Regression plots 
    a.lmplot
    b.regplot
5. Grid plots
    a.PairGrid
    b.JointGrid
    c.FacetGrid
# Out:
#   Input In [23]
#     1. Categorical plots
#        ^
# SyntaxError: invalid syntax

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby(['sex','time'])['day'].value_counts().sort_index()
# Out:
# sex     time
# Male    Lunch   Thur    30
#                 Fri      3
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     0
#                 Fri      7
#                 Sat     59
#                 Sun     58
# Female  Lunch   Thur    31
#                 Fri      4
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     1
#                 Fri      5
#                 Sat     28
#                 Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='time',data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(x='smoker',data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',y='sex',data=tips)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Priyanka Kala\OneDrive\Desktop\Training\plots.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Priyanka%20Kala/OneDrive/Desktop/Training/plots.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> sns.countplot(x='day',y='sex',data=tips)
#
# File c:\Users\Priyanka Kala\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Priyanka Kala\anaconda3\lib\site-packages\seaborn\categorical.py:3596, in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594     y = x
#    3595 elif x is not None and y is not None:
# -> 3596     raise ValueError("Cannot pass values for both `x` and `y`")
#    3598 plotter = _CountPlotter(
#    3599     x, y, hue, data, order, hue_order,
#    3600     estimator, ci, n_boot, units, seed,
#    3601     orient, color, palette, saturation,
#    3602     errcolor, errwidth, capsize, dodge
#    3603 )
#    3605 plotter.value_label = "count"
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
sns.countplot(x='day',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(x='day',y='total_bill',data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tips,hue='time',estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.lotp(x='day',y='total_bill',data=tips,hue='time',estimator=np.mean)
